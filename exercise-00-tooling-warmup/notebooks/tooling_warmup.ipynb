# %% [markdown]
# # Exercise 00 — First Flight
#
# This notebook rehearses the complete GitHub → Colab → CSV → validator workflow. Read each checkpoint before running it.

# %% [markdown]
# ## Checkpoint 1: identify your work
#
# Enter your name below. In a graded notebook this makes ownership explicit; it is not used in calculations.

# %%
STUDENT_NAME = "Camille Varendonck" # @param {type:"string"}
print(f'Welcome, {STUDENT_NAME}!')
# Out:
# Welcome, Camille Varendonck!

# %% [markdown]
# ## Checkpoint 2: obtain the course files
#
# A leading `!` runs a shell command. This clones the public repository into the temporary Colab runtime.

# %%
from pathlib import Path
import subprocess
REPO = Path('/content/modern-ai-ml-exercises')
if not REPO.exists():
    subprocess.run(['git','clone','-q','https://github.com/lathrahul/modern-ai-ml-exercises.git',str(REPO)],check=True)
DATA = REPO/'exercise-00-tooling-warmup/data/customer_activity.csv'
print('Repository ready:', REPO)
# Out:
# Repository ready: /content/modern-ai-ml-exercises

# %% [markdown]
# ## Checkpoint 3: load and inspect data

# %%
import numpy as np
import pandas as pd
activity = pd.read_csv(DATA)
print(activity.shape)
display(activity.head())
activity.describe()
# Out:
# (24, 4)
#   customer_id  visits  orders  revenue_usd
# 0     TOY-001      12       3       174.00
# 1     TOY-002       8       1        42.50
# 2     TOY-003       0       0         0.00
# 3     TOY-004      20       5       312.75
# 4     TOY-005       4       0         0.00
#           visits     orders  revenue_usd
# count  24.000000  24.000000    24.000000
# mean   11.958333   2.875000   185.470833
# std     7.931660   2.153107   181.770247
# min     0.000000   0.000000     0.000000
# 25%     5.750000   1.000000    73.625000
# 50%    11.500000   3.000000   150.500000
# 75%    17.250000   4.000000   209.125000
# max    30.000000   8.000000   700.000000

# %% [markdown]
# ## Checkpoint 4: complete the three calculations
#
# Replace the three `None` placeholders. Use the formulas in the problem brief. The `np.where` pattern handles zero denominators.

# %%
submission = activity[['customer_id']].copy()

# TODO 1: orders / visits, or 0 when visits are 0
submission['conversion_rate'] = None

# TODO 2: revenue_usd / orders, or 0 when orders are 0
submission['average_order_value'] = None

# TODO 3: 1 when orders >= 3 AND revenue_usd >= 150; otherwise 0
submission['priority_customer'] = None

display(submission.head())
# Out:
#   customer_id conversion_rate average_order_value priority_customer
# 0     TOY-001            None                None              None
# 1     TOY-002            None                None              None
# 2     TOY-003            None                None              None
# 3     TOY-004            None                None              None
# 4     TOY-005            None                None              None

# %%
submission = activity[['customer_id']].copy()

# Orders divided by visits; 0 when visits are 0
submission['conversion_rate'] = np.where(activity['visits'] > 0, activity['orders'] / activity['visits'],0)

# Revenue divided by orders; 0 when orders are 0
submission['average_order_value'] = np.where(activity['orders'] > 0, activity['revenue_usd'] / activity['orders'],0)

# 1 when both conditions are true; otherwise 0
submission['priority_customer'] = np.where((activity['orders'] >= 3) & (activity['revenue_usd'] >= 150),1,0)

display(submission.head())
# Out:
#   customer_id  conversion_rate  average_order_value  priority_customer
# 0     TOY-001            0.250                58.00                  1
# 1     TOY-002            0.125                42.50                  0
# 2     TOY-003            0.000                 0.00                  0
# 3     TOY-004            0.250                62.55                  1
# 4     TOY-005            0.000                 0.00                  0

# %% [markdown]
# ## Checkpoint 5: export and validate
#
# The validator gives a useful error when a column, ID, or calculation is wrong. Debug until it prints `Valid tooling submission`.

# %%
OUTPUT = Path('/content/toy_submission.csv')
submission.to_csv(OUTPUT,index=False)
validator = REPO/'exercise-00-tooling-warmup/checks/validate_submission.py'
result = subprocess.run(['python',str(validator),str(OUTPUT)],text=True,capture_output=True)
print(result.stdout or result.stderr)
if result.returncode != 0: raise RuntimeError('Validation failed—read the message above and fix the calculation cell.')
# Out:
# Valid tooling submission: 24 customers

# %% [markdown]
# ## Reflection
#
# Before downloading the notebook, add one sentence: What is the difference between the temporary Colab runtime and the files committed to GitHub?
#
# **Your answer:** The Colab runtime is temporary and its files disappear when the session ends, while files committed to GitHub are stored permanently in the repository.

# %% [markdown]
# ## Checkpoint 6: preserve, download, and submit your work
#
# 1. Select **File → Save a copy in Drive** while working. Do not use **Save a copy as a GitHub Gist**. The Drive copy is normally stored in **My Drive → Colab Notebooks**.
# 2. After validation passes and your reflection is complete, select **File → Download → Download .ipynb**. Rename the downloaded file `tooling_warmup.ipynb` if Colab adds `Copy of` to its name.
# 3. Run the cell below to download `toy_submission.csv`. Both downloads are normally stored in your computer's **Downloads** folder.
# 4. In your GitHub fork, create `tooling-warmup` from `main`. Confirm that the branch selector says `tooling-warmup`.
# 5. On that branch, replace `exercise-00-tooling-warmup/notebooks/tooling_warmup.ipynb` and add `exercise-00-tooling-warmup/toy_submission.csv`. Commit both uploads.
# 6. Open `https://github.com/YOUR_USERNAME/modern-ai-ml-exercises/compare/main...tooling-warmup`. Confirm that both repositories show your username, create the pull request, and leave it open. Submit its URL in Blackboard.

# %%
from google.colab import files
files.download(str(OUTPUT))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3160/804555124.py in <cell line: 0>()
#       1 from google.colab import files
# ----> 2 files.download(str(OUTPUT))
#
# NameError: name 'OUTPUT' is not defined
